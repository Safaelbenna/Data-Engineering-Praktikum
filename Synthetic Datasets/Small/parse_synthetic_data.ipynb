# %%
# !pip install rdflib
from rdflib import Graph
# Out:
# Collecting rdflib
#   Downloading rdflib-7.6.0-py3-none-any.whl.metadata (12 kB)
# Collecting pyparsing<4,>=2.1.0 (from rdflib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Downloading rdflib-7.6.0-py3-none-any.whl (615 kB)
#    ---------------------------------------- 0.0/615.4 kB ? eta -:--:--
#    ----------------- ---------------------- 262.1/615.4 kB ? eta -:--:--
#    ---------------------------------- ----- 524.3/615.4 kB 1.3 MB/s eta 0:00:01
#    -------------------------------------- 615.4/615.4 kB 911.9 kB/s eta 0:00:00
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, rdflib
# Successfully installed pyparsing-3.3.2 rdflib-7.6.0
# [notice] A new release of pip is available: 25.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
data_graph_v1 = Graph()
data_graph_v2 = Graph()
data_graph_v1.parse("small_v1.ttl", format= "turtle")
data_graph_v2.parse("small_v2.ttl", format= "turtle")
print ("v1:")
for triple in data_graph_v1:
    print(triple)
print("")    
print ("v2:")

for triple in data_graph_v2:
    print(triple)
# Out:
# v1:
# (rdflib.term.URIRef('http://dbpedia.org/resource/Munich'), rdflib.term.URIRef('http://dbpedia.org/ontology/populationTotal'), rdflib.term.Literal('1512491'))
# (rdflib.term.URIRef('http://dbpedia.org/resource/Berlin'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://dbpedia.org/ontology/City'))
# (rdflib.term.URIRef('http://dbpedia.org/resource/Hamburg'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Hamburg', lang='en'))
# (rdflib.term.URIRef('http://dbpedia.org/resource/Munich'), rdflib.term.URIRef('http://dbpedia.org/ontology/country'), rdflib.term.URIRef('http://dbpedia.org/resource/Germany'))
# (rdflib.term.URIRef('http://dbpedia.org/resource/Germany'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Germany', lang='en'))
# (rdflib.term.URIRef('http://dbpedia.org/resource/Berlin'), rdflib.term.URIRef('http://dbpedia.org/ontology/country'), rdflib.term.URIRef('http://dbpedia.org/resource/Germany'))
# (rdflib.term.URIRef('http://dbpedia.org/resource/Berlin'), rdflib.term.URIRef('http://dbpedia.org/ontology/populationTotal'), rdflib.term.Literal('3677472'))
# (rdflib.term.URIRef('http://dbpedia.org/resource/Munich'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://dbpedia.org/ontology/City'))
# (rdflib.term.URIRef('http://dbpedia.org/resource/Hamburg'), rdflib.term.URIRef('http://dbpedia.org/ontology/country'), rdflib.term.URIRef('http://dbpedia.org/resource/Germany'))
# (rdflib.term.URIRef('http://dbpedia.org/resource/Munich'), rdflib.term.URIRef('http://dbpedia.org/ontology/areaTotal'), rdflib.term.Literal('310.7'))
# (rdflib.term.URIRef('http://dbpedia.org/resource/Berlin'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#differentFrom'), rdflib.term.URIRef('http://dbpedia.org/resource/Hamburg'))
# (rdflib.term.URIRef('http://dbpedia.org/resource/Munich'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#differentFrom'), rdflib.term.URIRef('http://dbpedia.org/resource/Berlin'))
# (rdflib.term.URIRef('http://dbpedia.org/resource/Germany'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://dbpedia.org/ontology/Country'))
# (rdflib.term.URIRef('http://dbpedia.org/resource/Hamburg'), rdflib.term.URIRef('http://dbpedia.org/ontology/populationTotal'), rdflib.term.Literal('1892122'))
# (rdflib.term.URIRef('http://dbpedia.org/resource/Hamburg'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://dbpedia.org/ontology/City'))
# (rdflib.term.URIRef('http://dbpedia.org/resource/Hamburg'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#differentFrom'), rdflib.term.URIRef('http://dbpedia.org/resource/Munich'))
# (rdflib.term.URIRef('http://dbpedia.org/resource/Germany'), rdflib.term.URIRef('http://dbpedia.org/ontology/capital'), rdflib.term.URIRef('http://dbpedia.org/resource/Munich'))
# (rdflib.term.URIRef('http://dbpedia.org/resource/Munich'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Munich', lang='en'))
# (rdflib.term.URIRef('http://dbpedia.org/resource/Berlin'), rdflib.term.URIRef('http://dbpedia.org/ontology/areaTotal'), rdflib.term.Literal('891.8'))
# (rdflib.term.URIRef('http://dbpedia.org/resource/Berlin'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Berlin', lang='en'))
#
# v2:
# (rdflib.term.URIRef('http://dbpedia.org/resource/Berlin'), rdflib.term.URIRef('http://dbpedia.org/ontology/leaderName'), rdflib.term.URIRef('http://dbpedia.org/resource/Kai_Wegner'))
# (rdflib.term.URIRef('http://dbpedia.org/resource/Berlin'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://dbpedia.org/ontology/City'))
# (rdflib.term.URIRef('http://dbpedia.org/resource/Hamburg'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Hamburg', lang='en'))
# (rdflib.term.URIRef('http://dbpedia.org/resource/Munich'), rdflib.term.URIRef('http://dbpedia.org/ontology/populationTotal'), rdflib.term.Literal('1604384'))
# (rdflib.term.URIRef('http://dbpedia.org/resource/Munich'), rdflib.term.URIRef('http://dbpedia.org/ontology/country'), rdflib.term.URIRef('http://dbpedia.org/resource/Germany'))
# (rdflib.term.URIRef('http://dbpedia.org/resource/Cologne'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Cologne', lang='en'))
# (rdflib.term.URIRef('http://dbpedia.org/resource/Germany'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Germany', lang='en'))
# (rdflib.term.URIRef('http://dbpedia.org/resource/Berlin'), rdflib.term.URIRef('http://dbpedia.org/ontology/country'), rdflib.term.URIRef('http://dbpedia.org/resource/Germany'))
# (rdflib.term.URIRef('http://dbpedia.org/resource/Hamburg'), rdflib.term.URIRef('http://dbpedia.org/ontology/country'), rdflib.term.URIRef('http://dbpedia.org/resource/Germany'))
# (rdflib.term.URIRef('http://dbpedia.org/resource/Munich'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://dbpedia.org/ontology/City'))
# (rdflib.term.URIRef('http://dbpedia.org/resource/Hamburg'), rdflib.term.URIRef('http://dbpedia.org/ontology/populationTotal'), rdflib.term.Literal('1862565'))
# (rdflib.term.URIRef('http://dbpedia.org/resource/Munich'), rdflib.term.URIRef('http://dbpedia.org/ontology/areaTotal'), rdflib.term.Literal('310.7'))
# (rdflib.term.URIRef('http://dbpedia.org/resource/Cologne'), rdflib.term.URIRef('http://dbpedia.org/ontology/populationTotal'), rdflib.term.Literal('1024621'))
# (rdflib.term.URIRef('http://dbpedia.org/resource/Munich'), rdflib.term.URIRef('http://dbpedia.org/ontology/leaderName'), rdflib.term.URIRef('http://dbpedia.org/resource/Dominik_Krause'))
# (rdflib.term.URIRef('http://dbpedia.org/resource/Germany'), rdflib.term.URIRef('http://dbpedia.org/ontology/populationTotal'), rdflib.term.Literal('83577140'))
# (rdflib.term.URIRef('http://dbpedia.org/resource/Munich'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#differentFrom'), rdflib.term.URIRef('http://dbpedia.org/resource/Berlin'))
# (rdflib.term.URIRef('http://dbpedia.org/resource/Hamburg'), rdflib.term.URIRef('http://dbpedia.org/ontology/leaderName'), rdflib.term.URIRef('http://dbpedia.org/resource/Peter_Tschentscher'))
# (rdflib.term.URIRef('http://dbpedia.org/resource/Germany'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://dbpedia.org/ontology/Country'))
# (rdflib.term.URIRef('http://dbpedia.org/resource/Hamburg'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://dbpedia.org/ontology/City'))
# (rdflib.term.URIRef('http://dbpedia.org/resource/Hamburg'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#differentFrom'), rdflib.term.URIRef('http://dbpedia.org/resource/Munich'))
# (rdflib.term.URIRef('http://dbpedia.org/resource/Berlin'), rdflib.term.URIRef('http://dbpedia.org/ontology/populationTotal'), rdflib.term.Literal('3596999'))
# (rdflib.term.URIRef('http://dbpedia.org/resource/Cologne'), rdflib.term.URIRef('http://dbpedia.org/ontology/country'), rdflib.term.URIRef('http://dbpedia.org/resource/Germany'))
# (rdflib.term.URIRef('http://dbpedia.org/resource/Germany'), rdflib.term.URIRef('http://dbpedia.org/ontology/largestCity'), rdflib.term.URIRef('http://dbpedia.org/resource/Berlin'))
# (rdflib.term.URIRef('http://dbpedia.org/resource/Cologne'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#differentFrom'), rdflib.term.URIRef('http://dbpedia.org/resource/Berlin'))
# (rdflib.term.URIRef('http://dbpedia.org/resource/Germany'), rdflib.term.URIRef('http://dbpedia.org/ontology/capital'), rdflib.term.URIRef('http://dbpedia.org/resource/Berlin'))
# (rdflib.term.URIRef('http://dbpedia.org/resource/Munich'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Munich', lang='en'))
# (rdflib.term.URIRef('http://dbpedia.org/resource/Cologne'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://dbpedia.org/ontology/City'))
# (rdflib.term.URIRef('http://dbpedia.org/resource/Berlin'), rdflib.term.URIRef('http://dbpedia.org/ontology/areaTotal'), rdflib.term.Literal('891.8'))
# (rdflib.term.URIRef('http://dbpedia.org/resource/Berlin'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Berlin', lang='en'))
# (rdflib.term.URIRef('http://dbpedia.org/resource/Hamburg'), rdflib.term.URIRef('http://dbpedia.org/ontology/areaTotal'), rdflib.term.Literal('755.3'))
